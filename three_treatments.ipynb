# %% [markdown]
# # Causal ML example

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

from econml.dml import CausalForestDML
from econml.dml import LinearDML

np.random.seed(42)

# %% [markdown]
# ## Make data

# %%
n_samples = 10000

n_X = 2

## Features
X = np.random.normal(size=(n_samples, n_X))

# %% [markdown]
# ## Correlated (no confounder)

# %%
## Treatments (correlated)

# Mean vector (mu)
mu = [0, 0, 0]

# Define the covariance matrix (Sigma)
Sigma = [[1, 0.75, 0.75], 
         [0.75, 1, 0.75], 
         [0.75, 0.75, 1]]

# Generate the samples
samples = np.random.multivariate_normal(mean=mu, cov=Sigma, size=n_samples)

T0 = samples[:,0]
T1 = samples[:,1]
T2 = samples[:,2]

plt.plot(samples[:,0], samples[:,1], '.')
# plt.hexbin(samples[:,0], samples[:,1], gridsize=50)

# %%
## Outcome
bT0 = 3
bT1 = -5
bT2 = 2
bT0T1 = 1.5
bX1 = 5

Y = bT0 * T0 + bT1 * T1 + bT2 * T2 + bX1 * X[:,0] + np.random.normal(0.0, 1.0, size=(n_samples), )

# %%
# Create a dictionary where keys are column names and values are arrays
data_dict = {'X0': X[:,0], 
             'X1': X[:,1], 
             'T0': T0, 
             'T1': T1, 
             'T2': T2, 
             'y': Y}

# Create the DataFrame from the dictionary
df = pd.DataFrame(data_dict)

# %%
## Model 1
model = smf.ols(formula='y ~ T0 + T1 + T2', data = df)
results = model.fit()
# print(results.summary()) # View the regression results summary
results.params
# Out:
# Intercept    0.018614
# T0           2.929194
# T1          -4.828874
# T2           1.804014
# dtype: float64

# %%
## Model 2
model = smf.ols(formula='y ~ T0 + T1 + T2 + X0', data = df)
results = model.fit()
# print(results.summary()) # View the regression results summary
results.params
# Out:
# Intercept    0.001748
# T0           3.002826
# T1          -4.990368
# T2           1.982882
# X0           5.004867
# dtype: float64

# %% [markdown]
# ## Correlated (w/ confounder)

# %%
## Treatments (correlated)

# Mean vector (mu)
mu = [0, 0, 0]

# Define the covariance matrix (Sigma)
Sigma = [[1, 0.75, 0.75], 
         [0.75, 1, 0.75], 
         [0.75, 0.75, 1]]

# Generate the samples
samples = np.random.multivariate_normal(mean=mu, cov=Sigma, size=n_samples)

bT0X = 2
bT1X = 3
bT2X = -2

T0 = samples[:,0] + bT0X * X[:,0]
T1 = samples[:,1] + bT1X * X[:,0]
T2 = samples[:,2] + bT2X * X[:,0]

plt.plot(samples[:,0], samples[:,1], '.')
# plt.hexbin(samples[:,0], samples[:,1], gridsize=50)

# %%
## Outcome
bT0 = 3
bT1 = -5
bT2 = 2
bT0T1 = 1.5
bX1 = 5

Y = bT0 * T0 + bT1 * T1 + bT2 * T2 + bX1 * X[:,0] + np.random.normal(0.0, 1.0, size=(n_samples), )

# %%
# Create a dictionary where keys are column names and values are arrays
data_dict = {'X0': X[:,0], 
             'X1': X[:,1], 
             'T0': T0, 
             'T1': T1, 
             'y': Y}

# Create the DataFrame from the dictionary
df = pd.DataFrame(data_dict)

# %%
## Model 1
model = smf.ols(formula='y ~ T0 + T1 + T2', data = df)
results = model.fit()
# print(results.summary()) # View the regression results summary
results.params
# Out:
# Intercept   -0.000969
# T0           3.371773
# T1          -4.274910
# T2           1.002901
# dtype: float64

# %%
## Model 2
model = smf.ols(formula='y ~ T0 + T1 + T2 + X', data = df)
results = model.fit()
# print(results.summary()) # View the regression results summary
results.params
# Out:
# Intercept   -0.005235
# T0           2.996921
# T1          -4.994475
# T2           1.984391
# X[0]         4.963630
# X[1]         0.000210
# dtype: float64

# %% [markdown]
# ## Linear DML

# %%
T = np.vstack((T0,T1,T2)).T

# %% [markdown]
# ### Model 1

# %%
est = LinearDML(
    model_y='linear',
    model_t='linear',
    discrete_treatment=False
)

# %% [markdown]
# ### No confounder

# %%
# Fit the model
est.fit(Y, T)
est.marginal_ate_inference(T)
# Out:
# <table class="simpletable">
# <caption>Uncertainty of Mean Point Estimate</caption>
# <tr>
#    <td></td>  <th>mean_point</th> <th>stderr_mean</th>   <th>zstat</th>  <th>pvalue</th> <th>ci_mean_lower</th> <th>ci_mean_upper</th>
# </tr>
# <tr>
#   <th>T0</th>    <td>3.372</td>      <td>0.019</td>     <td>181.607</td>   <td>0.0</td>      <td>3.335</td>         <td>3.408</td>
# </tr>
# <tr>
#   <th>T1</th>   <td>-4.275</td>      <td>0.015</td>    <td>-284.805</td>   <td>0.0</td>     <td>-4.304</td>        <td>-4.246</td>
# </tr>
# <tr>
#   <th>T2</th>    <td>1.003</td>      <td>0.008</td>     <td>118.618</td>   <td>0.0</td>      <td>0.986</td>         <td>1.019</td>
# </tr>
# </table>
# <table class="simpletable">
# <caption>Distribution of Point Estimate</caption>
# <tr>
#    <td></td>  <th>std_point</th> <th>pct_point_lower</th> <th>pct_point_upper</th>
# </tr>
# <tr>
#   <th>T0</th>    <td>0.0</td>         <td>3.372</td>           <td>3.372</td>
# </tr>
# <tr>
#   <th>T1</th>    <td>0.0</td>        <td>-4.275</td>          <td>-4.275</td>
# </tr>
# <tr>
#   <th>T2</th>    <td>0.0</td>         <td>1.003</td>           <td>1.003</td>
# </tr>
# </table>
# <table class="simpletable">
# <caption>Total Variance of Point Estimate</caption>
# <tr>
#    <td></td>  <th>stderr_point</th> <th>ci_point_lower</th> <th>ci_point_upper</th>
# </tr>
# <tr>
#   <th>T0</th>     <td>0.019</td>         <td>3.335</td>          <td>3.408</td>
# </tr>
# <tr>
#   <th>T1</th>     <td>0.015</td>        <td>-4.304</td>         <td>-4.246</td>
# </tr>
# <tr>
#   <th>T2</th>     <td>0.008</td>         <td>0.986</td>          <td>1.019</td>
# </tr>
# </table>

# %% [markdown]
# ### Confounder

# %%
# Fit the model
est.fit(Y, T, W=X)
est.marginal_ate_inference(T)
# Out:
# <table class="simpletable">
# <caption>Uncertainty of Mean Point Estimate</caption>
# <tr>
#    <td></td>  <th>mean_point</th> <th>stderr_mean</th>   <th>zstat</th>  <th>pvalue</th> <th>ci_mean_lower</th> <th>ci_mean_upper</th>
# </tr>
# <tr>
#   <th>T0</th>    <td>2.997</td>      <td>0.017</td>     <td>179.373</td>   <td>0.0</td>      <td>2.964</td>         <td>3.03</td>
# </tr>
# <tr>
#   <th>T1</th>   <td>-4.995</td>      <td>0.017</td>    <td>-300.448</td>   <td>0.0</td>     <td>-5.027</td>        <td>-4.962</td>
# </tr>
# <tr>
#   <th>T2</th>    <td>1.985</td>      <td>0.017</td>     <td>119.259</td>   <td>0.0</td>      <td>1.952</td>         <td>2.018</td>
# </tr>
# </table>
# <table class="simpletable">
# <caption>Distribution of Point Estimate</caption>
# <tr>
#    <td></td>  <th>std_point</th> <th>pct_point_lower</th> <th>pct_point_upper</th>
# </tr>
# <tr>
#   <th>T0</th>    <td>0.0</td>         <td>2.997</td>           <td>2.997</td>
# </tr>
# <tr>
#   <th>T1</th>    <td>0.0</td>        <td>-4.995</td>          <td>-4.995</td>
# </tr>
# <tr>
#   <th>T2</th>    <td>0.0</td>         <td>1.985</td>           <td>1.985</td>
# </tr>
# </table>
# <table class="simpletable">
# <caption>Total Variance of Point Estimate</caption>
# <tr>
#    <td></td>  <th>stderr_point</th> <th>ci_point_lower</th> <th>ci_point_upper</th>
# </tr>
# <tr>
#   <th>T0</th>     <td>0.017</td>         <td>2.964</td>          <td>3.03</td>
# </tr>
# <tr>
#   <th>T1</th>     <td>0.017</td>        <td>-5.027</td>         <td>-4.962</td>
# </tr>
# <tr>
#   <th>T2</th>     <td>0.017</td>         <td>1.952</td>          <td>2.018</td>
# </tr>
# </table>
